# %% [markdown]
# <a href="https://colab.research.google.com/github/volzinnovation/btw25-bw-landesergebnis/blob/main/Analyse_Wahlergebnisse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://github.com/volzinnovation/btw25-bw-landesergebnis/raw/refs/heads/main/data/latest-btw25-bw-gemeinden-rel.csv
# !wget https://github.com/volzinnovation/btw25-bw-landesergebnis/raw/refs/heads/main/data/latest-btw25-bw-kreise-rel.csv
# Out:
# --2025-03-14 13:08:16--  https://github.com/volzinnovation/btw25-bw-landesergebnis/raw/refs/heads/main/data/latest-btw25-bw-gemeinden-rel.csv
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/volzinnovation/btw25-bw-landesergebnis/refs/heads/main/data/latest-btw25-bw-gemeinden-rel.csv [following]
# --2025-03-14 13:08:16--  https://raw.githubusercontent.com/volzinnovation/btw25-bw-landesergebnis/refs/heads/main/data/latest-btw25-bw-gemeinden-rel.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 816418 (797K) [application/octet-stream]
# ...

# %%
# prompt: load the two csv files into separate dataframes

import pandas as pd

g = pd.read_csv('latest-btw25-bw-gemeinden-rel.csv', encoding="latin-1")
k = pd.read_csv('latest-btw25-bw-kreise-rel.csv', encoding="latin-1")
y = g[(g['AGS'].str.startswith('08216')) | (g['AGS'].str.startswith('08211'))] # Nur WK RA&BAD
y.FREIE_WÄHLER_Zweitstimmen.sum()
# Out:
# 2611

# %%
g.FREIE_WÄHLER_Erststimmen_rel.max()
# Out:
# 0.1086723768736616

# %%
g.FREIE_WÄHLER_Erststimmen_rel.mean()
# Out:
# 0.03144380880982407

# %%
g.FREIE_WÄHLER_Erststimmen_rel.median()
# Out:
# 0.02939336877745925

# %%
g.FREIE_WÄHLER_Erststimmen.sum()/g.Gültige_Erststimmen.sum()
# Out:
# 0.02587460828711429

# %%
g.FREIE_WÄHLER_Zweitstimmen.sum()/g.Gültige_Zweitstimmen.sum()
# Out:
# 0.013589987598214923

# %%
g.Gültige_Zweitstimmen.sum()
# Out:
# 12698172

# %%
g.FREIE_WÄHLER_Zweitstimmen.sum()
# Out:
# 172568

# %%
g.FREIE_WÄHLER_Erststimmen.sum()
# Out:
# 327666.0

# %%
# prompt: which row has the maximum of FREIE_WÄHLER_Erststimmen_rel in dataframe g

g[g.FREIE_WÄHLER_Erststimmen_rel == g.FREIE_WÄHLER_Erststimmen_rel.max()].Gemeindename
# Out:
# 784    Efringen-Kirchen
# Name: Gemeindename, dtype: object

# %%
# prompt: Sort g by column FREIE_WÄHLER_Erststimmen_rel descending
g_sorted = g.sort_values(by='FREIE_WÄHLER_Erststimmen_rel', ascending=False)
y = g_sorted[(g_sorted['AGS'].str.startswith('08216')) | (g_sorted['AGS'].str.startswith('08211'))]
y = y.rename(columns={'FREIE_WÄHLER_Erststimmen_rel': 'Erstst_rel',
                      'FREIE_WÄHLER_Zweitstimmen_rel': 'Zweitst_rel',
                      'FREIE_WÄHLER_Erststimmen': 'Erststimmen',
                      'FREIE_WÄHLER_Zweitstimmen': 'Zweitstimmen'})
y[['Erstst_rel', 'Zweitst_rel']] = y[['Erstst_rel', 'Zweitst_rel']].apply(lambda y: round(y * 100, 1))

z = y[['Gemeindename', 'Erststimmen', 'Zweitstimmen', 'Erstst_rel', 'Zweitst_rel']]
z
# Out:
#                      Gemeindename  Erststimmen  Zweitstimmen  Erstst_rel  \
# 391             Gemeinde_Loffenau        152.0            44         9.7
# 388            Gemeinde_Iffezheim        159.0            78         4.8
# 384              Gemeinde_Forbach        117.0            79         4.2
# 378           Gemeinde_Bietigheim        168.0            84         4.2
# 389              Stadt_Kuppenheim        203.0           103         4.1
# 394          Gemeinde_Ottersweier        159.0            80         4.1
# 377          Gemeinde_Au_am_Rhein         93.0            53         4.1
# 379           Gemeinde_Bischweier         77.0            43         4.0
# 393             Gemeinde_Ötigheim        129.0            60         3.9
# 390               Stadt_Lichtenau        116.0            61         3.9
# 386               Stadt_Gernsbach        299.0           149         3.6
# 399         Gemeinde_Rheinmünster        146.0            66         3.5
# ...

# %%
# prompt: Sort g by column BSW Zweitstimmen descending
y = g_sorted[(g_sorted['AGS'].str.startswith('08216')) | (g_sorted['AGS'].str.startswith('08211'))]
y = y.rename(columns={
                      'BSW_Zweitstimmen_rel': 'Zweitst_rel',
                      'BSW_Zweitstimmen': 'Zweitstimmen'})
y[[ 'Zweitst_rel']] = y[[ 'Zweitst_rel']].apply(lambda y: round(y * 100, 1))

z = y[['Gemeindename',  'Zweitstimmen', 'Zweitst_rel']]
z
# Out:
#                      Gemeindename  Zweitstimmen  Zweitst_rel
# 391             Gemeinde_Loffenau            60          3.8
# 388            Gemeinde_Iffezheim           135          4.1
# 384              Gemeinde_Forbach            98          3.5
# 378           Gemeinde_Bietigheim           161          4.0
# 389              Stadt_Kuppenheim           187          3.8
# 394          Gemeinde_Ottersweier           154          3.9
# 377          Gemeinde_Au_am_Rhein            91          3.9
# 379           Gemeinde_Bischweier            76          3.9
# 393             Gemeinde_Ötigheim           112          3.4
# 390               Stadt_Lichtenau           156          5.2
# 386               Stadt_Gernsbach           317          3.8
# 399         Gemeinde_Rheinmünster           213          5.2
# 382          Gemeinde_Durmersheim           352          4.8
# 385                Stadt_Gaggenau           655          3.9
# ...

# %%
# prompt: DataFrame „z“ wird verwendet: save z as csv with with name 2023-02-23-273-FW.csv

# Save the DataFrame 'z' as a CSV file named '2023-02-23-273-FW.csv'.
z.to_csv('2023-02-27-273-BSW.csv', index=False) # Set index=False to avoid saving the DataFrame index.

# %%
k_sorted = k.sort_values(by='FREIE_WÄHLER_Zweitstimmen_rel', ascending=False)

# %%
# prompt: display top 10 of dataframe g_sorted and output colums Gemeindename and FREIE_WÄHLER_Erststimmen_rel

y[['Gemeindename', 'FREIE_WÄHLER_Erststimmen_rel', 'FREIE_WÄHLER_Zweitstimmen_rel']].head(1000)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-8344465184a1> in <cell line: 0>()
#       1 # prompt: display top 10 of dataframe g_sorted and output colums Gemeindename and FREIE_WÄHLER_Erststimmen_rel
#       2
# ----> 3 y[['Gemeindename', 'FREIE_WÄHLER_Erststimmen_rel', 'FREIE_WÄHLER_Zweitstimmen_rel']].head(1000)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# ...

# %%
x = k_sorted[['Wahlkreisname', 'FREIE_WÄHLER_Erststimmen_rel', 'FREIE_WÄHLER_Zweitstimmen_rel']]

# %%
# prompt: rename columns of x to Wahlkreis, Erststimmen, Zweitstimmen

x = x.rename(columns={'FREIE_WÄHLER_Erststimmen_rel': 'Erststimmen', 'FREIE_WÄHLER_Zweitstimmen_rel': 'Zweitstimmen'})

# %%
# prompt: Multiply values in Erststimmen and Zweitstimmen columns by 100 and round to 1 digit after comma

x[['Erststimmen', 'Zweitstimmen']] = x[['Erststimmen', 'Zweitstimmen']].apply(lambda x: round(x * 100, 2))
x

# %%
# prompt: Filter g_sorted where AGS starts with 08216 or 08211

# %%
y[['Gemeindename', 'FREIE_WÄHLER_Erststimmen_rel', 'FREIE_WÄHLER_Zweitstimmen_rel']]

# %%
# !rm latest-btw25-bw-gemeinden-rel.csv
# !rm latest-btw25-bw-kreise-rel.csv
